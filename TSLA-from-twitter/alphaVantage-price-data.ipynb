# %%
# !pip install alpha_vantage
import pandas as pd
import numpy as np
import sklearn
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
#import xgboost as xgb
from dateutil.easter import easter
import pickle
from datetime import datetime
from alpha_vantage.alphavantage import AlphaVantage
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
from alpha_vantage.cryptocurrencies import CryptoCurrencies
from matplotlib.pyplot import figure
import config
plt.style.use('seaborn')
# %matplotlib inline
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)
# Out:
# Requirement already satisfied: alpha_vantage in /Users/sullivanmyer/opt/anaconda3/lib/python3.7/site-packages (2.2.0)
# Requirement already satisfied: requests in /Users/sullivanmyer/opt/anaconda3/lib/python3.7/site-packages (from alpha_vantage) (2.22.0)
# Requirement already satisfied: aiohttp in /Users/sullivanmyer/opt/anaconda3/lib/python3.7/site-packages (from alpha_vantage) (3.6.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/sullivanmyer/opt/anaconda3/lib/python3.7/site-packages (from requests->alpha_vantage) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/sullivanmyer/opt/anaconda3/lib/python3.7/site-packages (from requests->alpha_vantage) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sullivanmyer/opt/anaconda3/lib/python3.7/site-packages (from requests->alpha_vantage) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/sullivanmyer/opt/anaconda3/lib/python3.7/site-packages (from requests->alpha_vantage) (1.24.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/sullivanmyer/opt/anaconda3/lib/python3.7/site-packages (from aiohttp->alpha_vantage) (1.4.2)
# Requirement already satisfied: multidict<5.0,>=4.5 in /Users/sullivanmyer/opt/anaconda3/lib/python3.7/site-packages (from aiohttp->alpha_vantage) (4.7.6)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /Users/sullivanmyer/opt/anaconda3/lib/python3.7/site-packages (from aiohttp->alpha_vantage) (3.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sullivanmyer/opt/anaconda3/lib/python3.7/site-packages (from aiohttp->alpha_vantage) (19.2.0)

# %%
# API key
key = config.ALPHAVANTAGE_API_KEY

# %%
# create timeseries object
ts = TimeSeries(key, output_format='pandas')

# %% [markdown]
# ## Tesla

# %%
ticker = 'TSLA'
data, meta_data = ts.get_intraday(symbol=ticker, outputsize='full', interval='1min')
data = data[::-1]
figure(num=None, figsize=(15, 6), dpi=80, facecolor='w', edgecolor='k')
data['4. close'].plot()

# %%
with open('pickle-folder/tsla_week3_price.pkl', 'wb') as f:
    pickle.dump(data, f)

# %%
with open('pickle-folder/tsla_week2_price.pkl', 'rb') as f:
    tempe = pickle.load(f)
tempe.iloc[769]
# Out:
# 1. open        808.76
# 2. high        809.15
# 3. low         808.00
# 4. close       808.00
# 5. volume    45435.00
# Name: 2020-05-19 16:00:00, dtype: float64

# %% [markdown]
# ## Amazon

# %%
ticker = 'AMZN'
data, meta_data = ts.get_intraday(symbol=ticker, outputsize='full', interval='1min')
data = data[::-1]
figure(num=None, figsize=(15, 6), dpi=80, facecolor='w', edgecolor='k')
data['4. close'].plot()

# %%
with open('amzn_week2_price.pkl', 'wb') as f:
    pickle.dump(data, f)

# %% [markdown]
# ## Apple

# %%
ticker = 'AAPL'
data, meta_data = ts.get_intraday(symbol=ticker, outputsize='full', interval='1min')
data = data[::-1]
figure(num=None, figsize=(15, 6), dpi=80, facecolor='w', edgecolor='k')
data['4. close'].plot()

# %%
with open('aapl_week2_price.pkl', 'wb') as f:
    pickle.dump(data, f)

# %% [markdown]
# ## Facebook

# %%
ticker = 'FB'
data, meta_data = ts.get_intraday(symbol=ticker, outputsize='full', interval='1min')
data = data[::-1]
figure(num=None, figsize=(15, 6), dpi=80, facecolor='w', edgecolor='k')
data['4. close'].plot()

# %%
with open('fb_week2_price.pkl', 'wb') as f:
    pickle.dump(data, f)

# %% [markdown]
# ## Netflix

# %%
ticker = 'NFLX'
data, meta_data = ts.get_intraday(symbol=ticker, outputsize='full', interval='1min')
data = data[::-1]
figure(num=None, figsize=(15, 6), dpi=80, facecolor='w', edgecolor='k')
data['4. close'].plot()

# %%
with open('nflx_week2_price.pkl', 'wb') as f:
    pickle.dump(data, f)
