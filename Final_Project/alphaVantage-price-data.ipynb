# %%
# !pip install alpha_vantage
import pandas as pd
import numpy as np
import sklearn
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
import xgboost as xgb
from dateutil.easter import easter
import pickle
from datetime import datetime
from alpha_vantage.alphavantage import AlphaVantage
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
from alpha_vantage.cryptocurrencies import CryptoCurrencies
from matplotlib.pyplot import figure
import config
plt.style.use('seaborn')
# %matplotlib inline
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)
# Out:
# Requirement already satisfied: alpha_vantage in /Users/lucas/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (2.1.3)
# Requirement already satisfied: requests in /Users/lucas/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from alpha_vantage) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/lucas/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests->alpha_vantage) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lucas/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests->alpha_vantage) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/lucas/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests->alpha_vantage) (1.25.8)
# Requirement already satisfied: idna<3,>=2.5 in /Users/lucas/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests->alpha_vantage) (2.9)
# Requirement already satisfied: polygon-api-client in /Users/lucas/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (0.1.2)
# Requirement already satisfied: websocket-client==0.56.0 in /Users/lucas/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from polygon-api-client) (0.56.0)
# Requirement already satisfied: websockets==8.0.2 in /Users/lucas/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from polygon-api-client) (8.0.2)
# Requirement already satisfied: six in /Users/lucas/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from websocket-client==0.56.0->polygon-api-client) (1.14.0)

# %%
# API key
key = config.ALPHAVANTAGE_API_KEY

# %%
# create timeseries object
ts = TimeSeries(key, output_format='pandas')

# %% [markdown]
# ## Tesla

# %%
ticker = 'TSLA'
data, meta_data = ts.get_intraday(symbol=ticker, outputsize='full', interval='1min')
data = data[::-1]
figure(num=None, figsize=(15, 6), dpi=80, facecolor='w', edgecolor='k')
data['4. close'].plot()

# %%
with open('tsla_week2_price.pkl', 'wb') as f:
    pickle.dump(data, f)

# %% [markdown]
# ## Amazon

# %%
ticker = 'AMZN'
data, meta_data = ts.get_intraday(symbol=ticker, outputsize='full', interval='1min')
data = data[::-1]
figure(num=None, figsize=(15, 6), dpi=80, facecolor='w', edgecolor='k')
data['4. close'].plot()

# %%
with open('amzn_week2_price.pkl', 'wb') as f:
    pickle.dump(data, f)

# %% [markdown]
# ## Apple

# %%
ticker = 'AAPL'
data, meta_data = ts.get_intraday(symbol=ticker, outputsize='full', interval='1min')
data = data[::-1]
figure(num=None, figsize=(15, 6), dpi=80, facecolor='w', edgecolor='k')
data['4. close'].plot()

# %%
with open('aapl_week2_price.pkl', 'wb') as f:
    pickle.dump(data, f)

# %% [markdown]
# ## Facebook

# %%
ticker = 'FB'
data, meta_data = ts.get_intraday(symbol=ticker, outputsize='full', interval='1min')
data = data[::-1]
figure(num=None, figsize=(15, 6), dpi=80, facecolor='w', edgecolor='k')
data['4. close'].plot()

# %%
with open('fb_week2_price.pkl', 'wb') as f:
    pickle.dump(data, f)

# %% [markdown]
# ## Netflix

# %%
ticker = 'NFLX'
data, meta_data = ts.get_intraday(symbol=ticker, outputsize='full', interval='1min')
data = data[::-1]
figure(num=None, figsize=(15, 6), dpi=80, facecolor='w', edgecolor='k')
data['4. close'].plot()

# %%
with open('nflx_week2_price.pkl', 'wb') as f:
    pickle.dump(data, f)
